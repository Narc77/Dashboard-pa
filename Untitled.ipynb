# %%
import pandas as pd
import numpy as np

# %%
cota = pd.read_excel('cota.xlsx').set_index('Data')
indices = pd.read_excel('indices.xlsx').set_index('Date')

# %%
cota_mensal = cota.resample('ME').last()

cota_mensal.loc['2015-03-23', 'Cota liq'] = 1.0
cota_mensal = cota_mensal.loc[:,'Cota liq'].sort_index()

# %%
print(indices.tail())
# Out:
#                 SPX      SPXT    Nasdaq   NasdaqT       IBOV   MSCI_WT  \
# Date
# 2025-09-25  6604.72  14639.18  24397.31  29625.46  145306.23  20174.29
# 2025-09-26  6643.70  14725.98  24503.85  29755.33  145446.66  20288.95
# 2025-09-29  6661.21  14764.92  24611.35  29885.88  146336.80  20357.24
# 2025-09-30  6688.46  14826.80  24679.99  29970.26  146237.02  20445.92
# 2025-10-01  6686.27  14826.80  24676.98  29968.57  145401.45  20445.92
#
#                MSCI_W  MSCI EMs   MSCI IT  USD/BRL  ...  MSCI TR   \
# Date                                                ...
# 2025-09-25  13594.964   1343.82  947.5456   5.3637  ...    533.61
# 2025-09-26  13671.981   1325.58  948.4963   5.3440  ...    535.52
# 2025-09-29  13716.845   1339.71  953.9150   5.3224  ...    537.71
# 2025-09-30  13776.274   1346.05  961.3742   5.3218  ...    540.07
# 2025-10-01  13776.274   1346.05  961.3742   5.3291  ...    540.07
#
#             MSCI TR BRL  ACWI Net TR USD  DAX TR USD  Nikkei 225 TR USD  \
# ...
